# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulmoiz4557-pixel/moiz-py/blob/main/MY%20First%20code%20on%20github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("my first code in github")
# Out:
# my first code in github

# %% [markdown]
# my first code on 2nd of May,2k26
