# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulmoiz4557-pixel/moiz-py/blob/main/Introduction_to_String_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introduction to string in python**

# %%
"hey there"    #with double quotes
'hey there'    #with single quotes
name='USMAN'
letter = name[1]
print(letter)
letter = name[-1]
print(letter)
# Out:
# S
# N

# %% [markdown]
# String is a set of characters. And can be written in both 'single' and "double" quotes. We can do much with strings like if we assign the string to a variable and want to know its any of index(letters) , we can print it using LISTs. as i mentioned one of the example above. I assigned the string 'USMAN' to a variable (letter) and i want to know the letter of the string which is on index 1. Remember: (INDEX ALWAYS STARTS FROM ZERO 0).i have to write the variable name in which the string is assigned then i have to use square brackets []. and write any of index number (existing) in it and print it using another varaible i.e i have used (letter) and index = [1] . now it displays the letter 'S', as the string 'USMAN' has the letter 'S' on index 1. Another goodness is we can also print its index nagetive. For example if i write the the variable and assign the string to it but now i put the index[-1] of name. It displays the letter 'N' on the screen..So here is the simple concepts of STRING.

# %% [markdown]
# ***STRING CONCATENATON AND REPETITION***

# %%
full_name = 'Usman' + ' Ghani' #concatenation
print(full_name)
full_name = 'Usman' + ' ' + 'Ghani' #another syntax
print(full_name)

name = 'Usman ' * 3 #repetition
print(name)         #prints 3 times 'Usman'
# Out:
# Usman Ghani
# Usman Ghani
# Usman Usman Usman

# %% [markdown]
# Concatenation refers to the operation of joining two or more strings end-to-end to form a single new string. In Python, you can achieve this using the + operator. As demonstrated in the notebook above. I assigned a variable of full_name to 'Usman' + ' Ghani' and by printing it displays Usman Ghani.
# And if change the syntax . As i wrote 'Usman' +''+ 'Ghani'.
# the output remains the same.
#
# **Repetition**
# On the other hand, Repeitition means to repeat the same string as many times you want. For example  i assigned a variable name = 3 * 'Usman' and when i print it. It displays the string 3 times.
#
#
# So the both are kool? Right.
# I hope you have been learnt it.

# %% [markdown]
# **Slicing String**

# %%
str = "program"    #case1
r = str[0:2]
print(r)

r2 = str[2:]       #case2
print(r2)

r3 = str[2:5]      #case3
print(r3)
# Out:
# pr
# ogram
# ogr

# %% [markdown]
# **Case1**
# String also supports slicing.
# which means getting characters in a specified range
# for example just take a look on above program.
# i initialized a string in a variable str and than i used **slicing**
# by defining the range of the variable containing string to a new variable.
# Note: Range includes first index but excludes last one.
# AS, i defined the range str[0:2] it doesn't includes the character on index 2.
# **Case2**
# if i do not specify the ending point of range e.g if i write r2 = str[2:] it starts from index 2 and continues till the end.
#
# **Case 3**
# If i define the range as [2:5] as mentioned in the program
# it prints from index 2 to 4 it do not prints the ending index point.
#
#
# It is how we use slicing. I hope you understand.

# %% [markdown]
# **Updating Strings**

# %%
str1 = "hey python!"               #main string
print("this is the main string:",str1)

print("updating string : -",str1[:3] + " david" )       #updating using slicing and concatenation
# Out:
# this is the main string: hey python
# updating string : - hey david

# %% [markdown]
# We can also update the string in python every timw we want.
# To understand consider the above example program in which i used one main string and i updated it later.
# **RECALL SLICING STRING and CONCATENATION**
# To update a string i used slicing as i defined the range of printing the string from index 0 to 3, and i used "+" as concatenation syntax and i have wrote the string " david" .
# Now if i print str1 it is the updated version of that.

# %% [markdown]
# **Special String Operators**

# %%
#example no 1
str = "programming"
if "pr" in str:         #using (in)
 print("exists")
else :
 print("not exists")
# Out:
# exists

# %%
#example no 2
str = "programming"
if "abc" not in str:    #using(not in)
 print("not exists")
else :
 print("exists")
# Out:
# not exists

# %% [markdown]
# These special string operators are also known as the **Membership Operators** these membership operators are "in" or "not in". Above mentioned examples are the most basic and simple examples of membership operators.
#
# for example let/assign (variable = str) and (string = programming)
# -In Example:1
# Here we write an if() function as if "pr" in str:
# we used a membership operator "in" and a part of string from any indexes . and checked for a particular condition.
# if that string exists in main string it will print "exists" otherwise it will print "not exists"
# this is a very simple concept.
# -In example 2:
# Here we write an if() function as if "abc" in str:   here we have written any other string which  doesn't exists in the string we assigned to the variable
# we used a membership operator "not in" . and checked for a particular condition.
# if that string not exists in main string it will print "not exists" otherwise it will print "exists"

# %% [markdown]
# For Feedback : abdulmoiz4557@gmail.com
