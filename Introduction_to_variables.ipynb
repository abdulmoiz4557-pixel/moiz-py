# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulmoiz4557-pixel/moiz-py/blob/main/Introduction_to_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A Python variable is a named storage location for data, acting as a container for values like numbers, text, or true/false.
# You assign values using the `=` operator, and Python automatically determines the variable's type.

# %%
n=100
print(n)

n=n+1
print(n)
# Out:
# 100
# 101
