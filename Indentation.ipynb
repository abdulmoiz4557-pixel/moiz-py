# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulmoiz4557-pixel/moiz-py/blob/main/Indentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=2
y=6
if x>y:
  print("x is greater") #4 space indent
else:
  print("y is greater")
# Out:
# y is greater

# %% [markdown]
# Step 1. i initailize a variable as x=2
# Step 2. then i initialized another var y=2
# Step 3. here i put an if function to chk the condition weather x is greater than y
# **when i hit enter right after a colon it automatically adds spaces moves the cursor to 4 spaces looks like i have pressed TAB but i didn't ... it moves the cursor automatically on next line known as indentation (4 spaces by default) as the python is user friendly and easy to use . its the goodness of python**
# whenever we use functions or loops, IDE automatically adds indentation.
# if i remove the indentation the interpreter detects it as an error and doesnt give the output. INdentation basically shows blocks in python functions.
